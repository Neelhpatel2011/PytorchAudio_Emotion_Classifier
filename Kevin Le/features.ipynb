# %%
import os
import time
import librosa
import torch
import torchaudio
import numpy as np
import pandas as pd
import librosa
from tqdm import tqdm
import time
from torchaudio.transforms import MFCC
import torchaudio.transforms as T

# %%
folder_path = 'C:/Users/kevin.KEVIN/Desktop/Audio/audio_files'

# %%
def extract_audio_features(filepath):
    # Load with torchaudio for other features
    waveform, sample_rate = torchaudio.load(filepath)
    waveform_np = waveform.numpy().squeeze()  # Convert to numpy for librosa processing

    result = torch.tensor([])

    # Ensure waveform is mono (if stereo, take mean across channels)
    if waveform.shape[0] > 1:
        waveform = torch.mean(waveform, dim=0, keepdim=True)

    # 1. Mel-frequency cepstral coefficients (MFCC) 
    # 13 for arithmetic mean and 13 for coefficient of variation
    mfcc_transform = torchaudio.transforms.MFCC(
        sample_rate=sample_rate, n_mfcc=13, melkwargs={"n_fft": 1024, "hop_length": 128}
    )
    mfccs = mfcc_transform(waveform)
    mfccs_mean = torch.mean(mfccs, dim=-1).squeeze()
    mfccs_std = torch.std(mfccs, dim=-1).squeeze()
    coef_variation = mfccs_std / (mfccs_mean + 1e-6)
    result = torch.cat((result, mfccs_mean, coef_variation), dim=0)

    # 2. Chroma feature (using librosa)
    # 12 for chroma mean
    stft = np.abs(librosa.stft(waveform_np, n_fft=512, hop_length=256))
    chroma = librosa.feature.chroma_stft(S=stft, sr=sample_rate)
    chroma_mean = torch.tensor(np.mean(chroma, axis=1))
    result = torch.cat((result, chroma_mean), dim=0)
    
    # 3. Mel-spectrogram
    # 128 for mel-spectrogram mean
    mel_transform = torchaudio.transforms.MelSpectrogram(sample_rate=sample_rate)
    mel_spec = mel_transform(waveform)
    mel_mean = torch.mean(mel_spec, dim=-1).squeeze()
    result = torch.cat((result, mel_mean), dim=0)

    # 4. Zero crossing rate
    # 398 for zero crossing rate
    zcr = librosa.feature.zero_crossing_rate(waveform_np, frame_length=2048, hop_length=512)
    zcr = zcr.flatten()
    result = torch.cat((result, torch.tensor(zcr)), dim=0)

    # 5. Root square energy
    # 398 for RMS energy
    rms = librosa.feature.rms(y=waveform_np, frame_length=2048, hop_length=512)
    rms = rms.flatten()
    rms_tensor = torch.tensor(rms, dtype=torch.float32)
    result = torch.cat((result, rms_tensor), dim=0)

    # 6. Harmonic-to-noise ratio
    # 1 for HNR mean
    harmonic = librosa.effects.harmonic(y=waveform_np)
    percussive = librosa.effects.percussive(y=waveform_np)
    hnr_mean = torch.tensor(np.mean(harmonic / (percussive + 1e-6))).unsqueeze(0)
    result = torch.cat((result, hnr_mean), dim=0)

    '''
    # 3. Zero crossing rate
    zero_crossings = (waveform[:, 1:] * waveform[:, :-1] < 0).sum(dim=1).float()
    zcr_mean = zero_crossings.mean()
    zcr_std = zero_crossings.std()
    #result = torch.cat((result, torch.tensor([zcr_mean, zcr_std])), dim=0)
    result = torch.cat((result, zero_crossings), dim=0)

    # 4. Harmonic-to-noise ratio (using librosa)
    harmonic = librosa.effects.harmonic(waveform_np)
    percussive = librosa.effects.percussive(waveform_np)
    hnr_mean = torch.tensor(np.mean(harmonic / (percussive + 1e-6))).unsqueeze(0)  # Add small constant to avoid division by zero
    hnr_std = torch.tensor(np.std(harmonic / (percussive + 1e-6))).unsqueeze(0)
    result = torch.cat((result, hnr_mean, hnr_std), dim=0)

    # 5. Mel-spectrogram
    
    '''

    return result.numpy(), os.path.basename(filepath)

# Main processing loop
folder_path = "C:/Users/kevin.KEVIN/Desktop/Audio/audio_files"
features_list = []
names_list = []

start_time = time.time()
for filename in tqdm(os.listdir(folder_path), desc="Processing audio files"):
    file_path = os.path.join(folder_path, filename)
    
    if filename.endswith('.wav'):
        features, name = extract_audio_features(file_path)
        features_list.append(features)
        names_list.append(name)

# Convert to DataFrame
final_data = pd.DataFrame(features_list)
final_data['name'] = names_list

print("Data shape:", final_data.shape)
print("Time taken:", time.time() - start_time)
# Out:
# Processing audio files:   0%|          | 0/2 [00:00<?, ?it/s]c:\Users\kevin.KEVIN\anaconda3\Lib\site-packages\torchaudio\functional\functional.py:584: UserWarning: At least one mel filterbank has all zero values. The value for `n_mels` (128) may be set too high. Or, the value for `n_freqs` (513) may be set too low.
#   warnings.warn(
# c:\Users\kevin.KEVIN\anaconda3\Lib\site-packages\torchaudio\functional\functional.py:584: UserWarning: At least one mel filterbank has all zero values. The value for `n_mels` (128) may be set too high. Or, the value for `n_freqs` (201) may be set too low.
#   warnings.warn(
# Processing audio files: 100%|██████████| 2/2 [00:00<00:00,  2.10it/s]
# Data shape: (2, 964)
# Time taken: 0.9608774185180664

# %%
final_data.shape
# Out:
# (2, 964)

# %%
mfcc_label_mean = "mfcc_arithmetic_mean_"
mfcc_coef_variation = "mfcc_coef_variation_"
chroma_label = "chroma_"
mel_spectrogram_label = "mel_spectrogram_"
zcr_label = "zero_crossing_rate_"
rms_label = "rms_"
hnr_label = "harmonic_to_noise_ratio_"

for column in range(len(final_data.columns)):
    if column < 13:
        final_data = final_data.rename(columns={column: mfcc_label_mean + str(column + 1)})
    elif column < 26:
        final_data = final_data.rename(columns={column: mfcc_coef_variation + str(column - 13 + 1)})
    elif column < 38:
        final_data = final_data.rename(columns={column: chroma_label + str(column - 26 + 1)})
    elif column < 166:
        final_data = final_data.rename(columns={column: mel_spectrogram_label + str(column - 38 + 1)})
    elif column < 564:
        final_data = final_data.rename(columns={column: zcr_label + str(column - 166 + 1)})
    elif column < 962:
        final_data = final_data.rename(columns={column: rms_label + str(column - 564 + 1)})
    else:
        final_data = final_data.rename(columns={column: hnr_label + str(column - 962 + 1)})

# %%
final_data
# Out:
#    mfcc_arithmetic_mean_1  mfcc_arithmetic_mean_2  mfcc_arithmetic_mean_3  \
# 0             -495.520599               79.076004              -11.591728
# 1             -569.218811               50.350269               18.299604
#
#    mfcc_arithmetic_mean_4  mfcc_arithmetic_mean_5  mfcc_arithmetic_mean_6  \
# 0                7.662766              -11.700242                5.068298
# 1               12.355660                1.612295               12.272793
#
#    mfcc_arithmetic_mean_7  mfcc_arithmetic_mean_8  mfcc_arithmetic_mean_9  \
# 0              -16.333410               -8.820160              -17.248329
# 1              -16.573362                2.895184               -4.377674
#
#    mfcc_arithmetic_mean_10  ...       rms_391       rms_392       rms_393  \
# 0                -7.643953  ...  6.743496e-07  6.743496e-07  6.743496e-07
# 1               -11.422575  ...           NaN           NaN           NaN
#
#    rms_394  rms_395   rms_396   rms_397   rms_398  harmonic_to_noise_ratio_1  \
# 0      0.0      0.0  0.000001  0.000002  0.000002                  13.971914
# 1      NaN      NaN       NaN       NaN       NaN                        NaN
#
#           name
# 0  audio_1.wav
# 1  audio_2.wav
#
# [2 rows x 964 columns]

# %%
final_data.columns
# Out:
# Index(['mfcc_arithmetic_mean_1', 'mfcc_arithmetic_mean_2',
#        'mfcc_arithmetic_mean_3', 'mfcc_arithmetic_mean_4',
#        'mfcc_arithmetic_mean_5', 'mfcc_arithmetic_mean_6',
#        'mfcc_arithmetic_mean_7', 'mfcc_arithmetic_mean_8',
#        'mfcc_arithmetic_mean_9', 'mfcc_arithmetic_mean_10',
#        ...
#        'rms_391', 'rms_392', 'rms_393', 'rms_394', 'rms_395', 'rms_396',
#        'rms_397', 'rms_398', 'harmonic_to_noise_ratio_1', 'name'],
#       dtype='object', length=964)

# %%
for column in final_data.columns:
    print(column)
# Out:
# mfcc_arithmetic_mean_1
# mfcc_arithmetic_mean_2
# mfcc_arithmetic_mean_3
# mfcc_arithmetic_mean_4
# mfcc_arithmetic_mean_5
# mfcc_arithmetic_mean_6
# mfcc_arithmetic_mean_7
# mfcc_arithmetic_mean_8
# mfcc_arithmetic_mean_9
# mfcc_arithmetic_mean_10
# mfcc_arithmetic_mean_11
# mfcc_arithmetic_mean_12
# mfcc_arithmetic_mean_13
# mfcc_coef_variation_1
# mfcc_coef_variation_2
# mfcc_coef_variation_3
# mfcc_coef_variation_4
# mfcc_coef_variation_5
# mfcc_coef_variation_6
# mfcc_coef_variation_7
# mfcc_coef_variation_8
# mfcc_coef_variation_9
# mfcc_coef_variation_10
# mfcc_coef_variation_11
# mfcc_coef_variation_12
# mfcc_coef_variation_13
# chroma_1
# chroma_2
# chroma_3
# chroma_4
# chroma_5
# chroma_6
# chroma_7
# chroma_8
# chroma_9
# chroma_10
# chroma_11
# chroma_12
# mel_spectrogram_1
# mel_spectrogram_2
# mel_spectrogram_3
# mel_spectrogram_4
# mel_spectrogram_5
# mel_spectrogram_6
# mel_spectrogram_7
# mel_spectrogram_8
# mel_spectrogram_9
# mel_spectrogram_10
# mel_spectrogram_11
# mel_spectrogram_12
# mel_spectrogram_13
# mel_spectrogram_14
# mel_spectrogram_15
# mel_spectrogram_16
# mel_spectrogram_17
# mel_spectrogram_18
# mel_spectrogram_19
# mel_spectrogram_20
# mel_spectrogram_21
# mel_spectrogram_22
# mel_spectrogram_23
# mel_spectrogram_24
# mel_spectrogram_25
# mel_spectrogram_26
# mel_spectrogram_27
# mel_spectrogram_28
# mel_spectrogram_29
# mel_spectrogram_30
# mel_spectrogram_31
# mel_spectrogram_32
# mel_spectrogram_33
# mel_spectrogram_34
# mel_spectrogram_35
# mel_spectrogram_36
# mel_spectrogram_37
# mel_spectrogram_38
# mel_spectrogram_39
# mel_spectrogram_40
# mel_spectrogram_41
# mel_spectrogram_42
# mel_spectrogram_43
# mel_spectrogram_44
# mel_spectrogram_45
# mel_spectrogram_46
# mel_spectrogram_47
# mel_spectrogram_48
# mel_spectrogram_49
# mel_spectrogram_50
# mel_spectrogram_51
# mel_spectrogram_52
# mel_spectrogram_53
# mel_spectrogram_54
# mel_spectrogram_55
# mel_spectrogram_56
# mel_spectrogram_57
# mel_spectrogram_58
# mel_spectrogram_59
# mel_spectrogram_60
# mel_spectrogram_61
# mel_spectrogram_62
# mel_spectrogram_63
# mel_spectrogram_64
# mel_spectrogram_65
# mel_spectrogram_66
# mel_spectrogram_67
# mel_spectrogram_68
# mel_spectrogram_69
# mel_spectrogram_70
# mel_spectrogram_71
# mel_spectrogram_72
# mel_spectrogram_73
# mel_spectrogram_74
# mel_spectrogram_75
# mel_spectrogram_76
# mel_spectrogram_77
# mel_spectrogram_78
# mel_spectrogram_79
# mel_spectrogram_80
# mel_spectrogram_81
# mel_spectrogram_82
# mel_spectrogram_83
# mel_spectrogram_84
# mel_spectrogram_85
# mel_spectrogram_86
# mel_spectrogram_87
# mel_spectrogram_88
# mel_spectrogram_89
# mel_spectrogram_90
# mel_spectrogram_91
# mel_spectrogram_92
# mel_spectrogram_93
# mel_spectrogram_94
# mel_spectrogram_95
# mel_spectrogram_96
# mel_spectrogram_97
# mel_spectrogram_98
# mel_spectrogram_99
# mel_spectrogram_100
# mel_spectrogram_101
# mel_spectrogram_102
# mel_spectrogram_103
# mel_spectrogram_104
# mel_spectrogram_105
# mel_spectrogram_106
# mel_spectrogram_107
# mel_spectrogram_108
# mel_spectrogram_109
# mel_spectrogram_110
# mel_spectrogram_111
# mel_spectrogram_112
# mel_spectrogram_113
# mel_spectrogram_114
# mel_spectrogram_115
# mel_spectrogram_116
# mel_spectrogram_117
# mel_spectrogram_118
# mel_spectrogram_119
# mel_spectrogram_120
# mel_spectrogram_121
# mel_spectrogram_122
# mel_spectrogram_123
# mel_spectrogram_124
# mel_spectrogram_125
# mel_spectrogram_126
# mel_spectrogram_127
# mel_spectrogram_128
# zero_crossing_rate_1
# zero_crossing_rate_2
# zero_crossing_rate_3
# zero_crossing_rate_4
# zero_crossing_rate_5
# zero_crossing_rate_6
# zero_crossing_rate_7
# zero_crossing_rate_8
# zero_crossing_rate_9
# zero_crossing_rate_10
# zero_crossing_rate_11
# zero_crossing_rate_12
# zero_crossing_rate_13
# zero_crossing_rate_14
# zero_crossing_rate_15
# zero_crossing_rate_16
# zero_crossing_rate_17
# zero_crossing_rate_18
# zero_crossing_rate_19
# zero_crossing_rate_20
# zero_crossing_rate_21
# zero_crossing_rate_22
# zero_crossing_rate_23
# zero_crossing_rate_24
# zero_crossing_rate_25
# zero_crossing_rate_26
# zero_crossing_rate_27
# zero_crossing_rate_28
# zero_crossing_rate_29
# zero_crossing_rate_30
# zero_crossing_rate_31
# zero_crossing_rate_32
# zero_crossing_rate_33
# zero_crossing_rate_34
# zero_crossing_rate_35
# zero_crossing_rate_36
# zero_crossing_rate_37
# zero_crossing_rate_38
# zero_crossing_rate_39
# zero_crossing_rate_40
# zero_crossing_rate_41
# zero_crossing_rate_42
# zero_crossing_rate_43
# zero_crossing_rate_44
# zero_crossing_rate_45
# zero_crossing_rate_46
# zero_crossing_rate_47
# zero_crossing_rate_48
# zero_crossing_rate_49
# zero_crossing_rate_50
# zero_crossing_rate_51
# zero_crossing_rate_52
# zero_crossing_rate_53
# zero_crossing_rate_54
# zero_crossing_rate_55
# zero_crossing_rate_56
# zero_crossing_rate_57
# zero_crossing_rate_58
# zero_crossing_rate_59
# zero_crossing_rate_60
# zero_crossing_rate_61
# zero_crossing_rate_62
# zero_crossing_rate_63
# zero_crossing_rate_64
# zero_crossing_rate_65
# zero_crossing_rate_66
# zero_crossing_rate_67
# zero_crossing_rate_68
# zero_crossing_rate_69
# zero_crossing_rate_70
# zero_crossing_rate_71
# zero_crossing_rate_72
# zero_crossing_rate_73
# zero_crossing_rate_74
# zero_crossing_rate_75
# zero_crossing_rate_76
# zero_crossing_rate_77
# zero_crossing_rate_78
# zero_crossing_rate_79
# zero_crossing_rate_80
# zero_crossing_rate_81
# zero_crossing_rate_82
# zero_crossing_rate_83
# zero_crossing_rate_84
# zero_crossing_rate_85
# zero_crossing_rate_86
# zero_crossing_rate_87
# zero_crossing_rate_88
# zero_crossing_rate_89
# zero_crossing_rate_90
# zero_crossing_rate_91
# zero_crossing_rate_92
# zero_crossing_rate_93
# zero_crossing_rate_94
# zero_crossing_rate_95
# zero_crossing_rate_96
# zero_crossing_rate_97
# zero_crossing_rate_98
# zero_crossing_rate_99
# zero_crossing_rate_100
# zero_crossing_rate_101
# zero_crossing_rate_102
# zero_crossing_rate_103
# zero_crossing_rate_104
# zero_crossing_rate_105
# zero_crossing_rate_106
# zero_crossing_rate_107
# zero_crossing_rate_108
# zero_crossing_rate_109
# zero_crossing_rate_110
# zero_crossing_rate_111
# zero_crossing_rate_112
# zero_crossing_rate_113
# zero_crossing_rate_114
# zero_crossing_rate_115
# zero_crossing_rate_116
# zero_crossing_rate_117
# zero_crossing_rate_118
# zero_crossing_rate_119
# zero_crossing_rate_120
# zero_crossing_rate_121
# zero_crossing_rate_122
# zero_crossing_rate_123
# zero_crossing_rate_124
# zero_crossing_rate_125
# zero_crossing_rate_126
# zero_crossing_rate_127
# zero_crossing_rate_128
# zero_crossing_rate_129
# zero_crossing_rate_130
# zero_crossing_rate_131
# zero_crossing_rate_132
# zero_crossing_rate_133
# zero_crossing_rate_134
# zero_crossing_rate_135
# zero_crossing_rate_136
# zero_crossing_rate_137
# zero_crossing_rate_138
# zero_crossing_rate_139
# zero_crossing_rate_140
# zero_crossing_rate_141
# zero_crossing_rate_142
# zero_crossing_rate_143
# zero_crossing_rate_144
# zero_crossing_rate_145
# zero_crossing_rate_146
# zero_crossing_rate_147
# zero_crossing_rate_148
# zero_crossing_rate_149
# zero_crossing_rate_150
# zero_crossing_rate_151
# zero_crossing_rate_152
# zero_crossing_rate_153
# zero_crossing_rate_154
# zero_crossing_rate_155
# zero_crossing_rate_156
# zero_crossing_rate_157
# zero_crossing_rate_158
# zero_crossing_rate_159
# zero_crossing_rate_160
# zero_crossing_rate_161
# zero_crossing_rate_162
# zero_crossing_rate_163
# zero_crossing_rate_164
# zero_crossing_rate_165
# zero_crossing_rate_166
# zero_crossing_rate_167
# zero_crossing_rate_168
# zero_crossing_rate_169
# zero_crossing_rate_170
# zero_crossing_rate_171
# zero_crossing_rate_172
# zero_crossing_rate_173
# zero_crossing_rate_174
# zero_crossing_rate_175
# zero_crossing_rate_176
# zero_crossing_rate_177
# zero_crossing_rate_178
# zero_crossing_rate_179
# zero_crossing_rate_180
# zero_crossing_rate_181
# zero_crossing_rate_182
# zero_crossing_rate_183
# zero_crossing_rate_184
# zero_crossing_rate_185
# zero_crossing_rate_186
# zero_crossing_rate_187
# zero_crossing_rate_188
# zero_crossing_rate_189
# zero_crossing_rate_190
# zero_crossing_rate_191
# zero_crossing_rate_192
# zero_crossing_rate_193
# zero_crossing_rate_194
# zero_crossing_rate_195
# zero_crossing_rate_196
# zero_crossing_rate_197
# zero_crossing_rate_198
# zero_crossing_rate_199
# zero_crossing_rate_200
# zero_crossing_rate_201
# zero_crossing_rate_202
# zero_crossing_rate_203
# zero_crossing_rate_204
# zero_crossing_rate_205
# zero_crossing_rate_206
# zero_crossing_rate_207
# zero_crossing_rate_208
# zero_crossing_rate_209
# zero_crossing_rate_210
# zero_crossing_rate_211
# zero_crossing_rate_212
# zero_crossing_rate_213
# zero_crossing_rate_214
# zero_crossing_rate_215
# zero_crossing_rate_216
# zero_crossing_rate_217
# zero_crossing_rate_218
# zero_crossing_rate_219
# zero_crossing_rate_220
# zero_crossing_rate_221
# zero_crossing_rate_222
# zero_crossing_rate_223
# zero_crossing_rate_224
# zero_crossing_rate_225
# zero_crossing_rate_226
# zero_crossing_rate_227
# zero_crossing_rate_228
# zero_crossing_rate_229
# zero_crossing_rate_230
# zero_crossing_rate_231
# zero_crossing_rate_232
# zero_crossing_rate_233
# zero_crossing_rate_234
# zero_crossing_rate_235
# zero_crossing_rate_236
# zero_crossing_rate_237
# zero_crossing_rate_238
# zero_crossing_rate_239
# zero_crossing_rate_240
# zero_crossing_rate_241
# zero_crossing_rate_242
# zero_crossing_rate_243
# zero_crossing_rate_244
# zero_crossing_rate_245
# zero_crossing_rate_246
# zero_crossing_rate_247
# zero_crossing_rate_248
# zero_crossing_rate_249
# zero_crossing_rate_250
# zero_crossing_rate_251
# zero_crossing_rate_252
# zero_crossing_rate_253
# zero_crossing_rate_254
# zero_crossing_rate_255
# zero_crossing_rate_256
# zero_crossing_rate_257
# zero_crossing_rate_258
# zero_crossing_rate_259
# zero_crossing_rate_260
# zero_crossing_rate_261
# zero_crossing_rate_262
# zero_crossing_rate_263
# zero_crossing_rate_264
# zero_crossing_rate_265
# zero_crossing_rate_266
# zero_crossing_rate_267
# zero_crossing_rate_268
# zero_crossing_rate_269
# zero_crossing_rate_270
# zero_crossing_rate_271
# zero_crossing_rate_272
# zero_crossing_rate_273
# zero_crossing_rate_274
# zero_crossing_rate_275
# zero_crossing_rate_276
# zero_crossing_rate_277
# zero_crossing_rate_278
# zero_crossing_rate_279
# zero_crossing_rate_280
# zero_crossing_rate_281
# zero_crossing_rate_282
# zero_crossing_rate_283
# zero_crossing_rate_284
# zero_crossing_rate_285
# zero_crossing_rate_286
# zero_crossing_rate_287
# zero_crossing_rate_288
# zero_crossing_rate_289
# zero_crossing_rate_290
# zero_crossing_rate_291
# zero_crossing_rate_292
# zero_crossing_rate_293
# zero_crossing_rate_294
# zero_crossing_rate_295
# zero_crossing_rate_296
# zero_crossing_rate_297
# zero_crossing_rate_298
# zero_crossing_rate_299
# zero_crossing_rate_300
# zero_crossing_rate_301
# zero_crossing_rate_302
# zero_crossing_rate_303
# zero_crossing_rate_304
# zero_crossing_rate_305
# zero_crossing_rate_306
# zero_crossing_rate_307
# zero_crossing_rate_308
# zero_crossing_rate_309
# zero_crossing_rate_310
# zero_crossing_rate_311
# zero_crossing_rate_312
# zero_crossing_rate_313
# zero_crossing_rate_314
# zero_crossing_rate_315
# zero_crossing_rate_316
# zero_crossing_rate_317
# zero_crossing_rate_318
# zero_crossing_rate_319
# zero_crossing_rate_320
# zero_crossing_rate_321
# zero_crossing_rate_322
# zero_crossing_rate_323
# zero_crossing_rate_324
# zero_crossing_rate_325
# zero_crossing_rate_326
# zero_crossing_rate_327
# zero_crossing_rate_328
# zero_crossing_rate_329
# zero_crossing_rate_330
# zero_crossing_rate_331
# zero_crossing_rate_332
# zero_crossing_rate_333
# zero_crossing_rate_334
# zero_crossing_rate_335
# zero_crossing_rate_336
# zero_crossing_rate_337
# zero_crossing_rate_338
# zero_crossing_rate_339
# zero_crossing_rate_340
# zero_crossing_rate_341
# zero_crossing_rate_342
# zero_crossing_rate_343
# zero_crossing_rate_344
# zero_crossing_rate_345
# zero_crossing_rate_346
# zero_crossing_rate_347
# zero_crossing_rate_348
# zero_crossing_rate_349
# zero_crossing_rate_350
# zero_crossing_rate_351
# zero_crossing_rate_352
# zero_crossing_rate_353
# zero_crossing_rate_354
# zero_crossing_rate_355
# zero_crossing_rate_356
# zero_crossing_rate_357
# zero_crossing_rate_358
# zero_crossing_rate_359
# zero_crossing_rate_360
# zero_crossing_rate_361
# zero_crossing_rate_362
# zero_crossing_rate_363
# zero_crossing_rate_364
# zero_crossing_rate_365
# zero_crossing_rate_366
# zero_crossing_rate_367
# zero_crossing_rate_368
# zero_crossing_rate_369
# zero_crossing_rate_370
# zero_crossing_rate_371
# zero_crossing_rate_372
# zero_crossing_rate_373
# zero_crossing_rate_374
# zero_crossing_rate_375
# zero_crossing_rate_376
# zero_crossing_rate_377
# zero_crossing_rate_378
# zero_crossing_rate_379
# zero_crossing_rate_380
# zero_crossing_rate_381
# zero_crossing_rate_382
# zero_crossing_rate_383
# zero_crossing_rate_384
# zero_crossing_rate_385
# zero_crossing_rate_386
# zero_crossing_rate_387
# zero_crossing_rate_388
# zero_crossing_rate_389
# zero_crossing_rate_390
# zero_crossing_rate_391
# zero_crossing_rate_392
# zero_crossing_rate_393
# zero_crossing_rate_394
# zero_crossing_rate_395
# zero_crossing_rate_396
# zero_crossing_rate_397
# zero_crossing_rate_398
# rms_1
# rms_2
# rms_3
# rms_4
# rms_5
# rms_6
# rms_7
# rms_8
# rms_9
# rms_10
# rms_11
# rms_12
# rms_13
# rms_14
# rms_15
# rms_16
# rms_17
# rms_18
# rms_19
# rms_20
# rms_21
# rms_22
# rms_23
# rms_24
# rms_25
# rms_26
# rms_27
# rms_28
# rms_29
# rms_30
# rms_31
# rms_32
# rms_33
# rms_34
# rms_35
# rms_36
# rms_37
# rms_38
# rms_39
# rms_40
# rms_41
# rms_42
# rms_43
# rms_44
# rms_45
# rms_46
# rms_47
# rms_48
# rms_49
# rms_50
# rms_51
# rms_52
# rms_53
# rms_54
# rms_55
# rms_56
# rms_57
# rms_58
# rms_59
# rms_60
# rms_61
# rms_62
# rms_63
# rms_64
# rms_65
# rms_66
# rms_67
# rms_68
# rms_69
# rms_70
# rms_71
# rms_72
# rms_73
# rms_74
# rms_75
# rms_76
# rms_77
# rms_78
# rms_79
# rms_80
# rms_81
# rms_82
# rms_83
# rms_84
# rms_85
# rms_86
# rms_87
# rms_88
# rms_89
# rms_90
# rms_91
# rms_92
# rms_93
# rms_94
# rms_95
# rms_96
# rms_97
# rms_98
# rms_99
# rms_100
# rms_101
# rms_102
# rms_103
# rms_104
# rms_105
# rms_106
# rms_107
# rms_108
# rms_109
# rms_110
# rms_111
# rms_112
# rms_113
# rms_114
# rms_115
# rms_116
# rms_117
# rms_118
# rms_119
# rms_120
# rms_121
# rms_122
# rms_123
# rms_124
# rms_125
# rms_126
# rms_127
# rms_128
# rms_129
# rms_130
# rms_131
# rms_132
# rms_133
# rms_134
# rms_135
# rms_136
# rms_137
# rms_138
# rms_139
# rms_140
# rms_141
# rms_142
# rms_143
# rms_144
# rms_145
# rms_146
# rms_147
# rms_148
# rms_149
# rms_150
# rms_151
# rms_152
# rms_153
# rms_154
# rms_155
# rms_156
# rms_157
# rms_158
# rms_159
# rms_160
# rms_161
# rms_162
# rms_163
# rms_164
# rms_165
# rms_166
# rms_167
# rms_168
# rms_169
# rms_170
# rms_171
# rms_172
# rms_173
# rms_174
# rms_175
# rms_176
# rms_177
# rms_178
# rms_179
# rms_180
# rms_181
# rms_182
# rms_183
# rms_184
# rms_185
# rms_186
# rms_187
# rms_188
# rms_189
# rms_190
# rms_191
# rms_192
# rms_193
# rms_194
# rms_195
# rms_196
# rms_197
# rms_198
# rms_199
# rms_200
# rms_201
# rms_202
# rms_203
# rms_204
# rms_205
# rms_206
# rms_207
# rms_208
# rms_209
# rms_210
# rms_211
# rms_212
# rms_213
# rms_214
# rms_215
# rms_216
# rms_217
# rms_218
# rms_219
# rms_220
# rms_221
# rms_222
# rms_223
# rms_224
# rms_225
# rms_226
# rms_227
# rms_228
# rms_229
# rms_230
# rms_231
# rms_232
# rms_233
# rms_234
# rms_235
# rms_236
# rms_237
# rms_238
# rms_239
# rms_240
# rms_241
# rms_242
# rms_243
# rms_244
# rms_245
# rms_246
# rms_247
# rms_248
# rms_249
# rms_250
# rms_251
# rms_252
# rms_253
# rms_254
# rms_255
# rms_256
# rms_257
# rms_258
# rms_259
# rms_260
# rms_261
# rms_262
# rms_263
# rms_264
# rms_265
# rms_266
# rms_267
# rms_268
# rms_269
# rms_270
# rms_271
# rms_272
# rms_273
# rms_274
# rms_275
# rms_276
# rms_277
# rms_278
# rms_279
# rms_280
# rms_281
# rms_282
# rms_283
# rms_284
# rms_285
# rms_286
# rms_287
# rms_288
# rms_289
# rms_290
# rms_291
# rms_292
# rms_293
# rms_294
# rms_295
# rms_296
# rms_297
# rms_298
# rms_299
# rms_300
# rms_301
# rms_302
# rms_303
# rms_304
# rms_305
# rms_306
# rms_307
# rms_308
# rms_309
# rms_310
# rms_311
# rms_312
# rms_313
# rms_314
# rms_315
# rms_316
# rms_317
# rms_318
# rms_319
# rms_320
# rms_321
# rms_322
# rms_323
# rms_324
# rms_325
# rms_326
# rms_327
# rms_328
# rms_329
# rms_330
# rms_331
# rms_332
# rms_333
# rms_334
# rms_335
# rms_336
# rms_337
# rms_338
# rms_339
# rms_340
# rms_341
# rms_342
# rms_343
# rms_344
# rms_345
# rms_346
# rms_347
# rms_348
# rms_349
# rms_350
# rms_351
# rms_352
# rms_353
# rms_354
# rms_355
# rms_356
# rms_357
# rms_358
# rms_359
# rms_360
# rms_361
# rms_362
# rms_363
# rms_364
# rms_365
# rms_366
# rms_367
# rms_368
# rms_369
# rms_370
# rms_371
# rms_372
# rms_373
# rms_374
# rms_375
# rms_376
# rms_377
# rms_378
# rms_379
# rms_380
# rms_381
# rms_382
# rms_383
# rms_384
# rms_385
# rms_386
# rms_387
# rms_388
# rms_389
# rms_390
# rms_391
# rms_392
# rms_393
# rms_394
# rms_395
# rms_396
# rms_397
# rms_398
# harmonic_to_noise_ratio_1
# name
